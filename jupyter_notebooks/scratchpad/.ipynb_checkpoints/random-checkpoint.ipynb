# %% [markdown]
# # Statistical Regularity

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
random.seed(44)
trials =[]
outcomes =[]
relative_freq = []
h=0;t=0
for x in range(1,1001):
    trials.append(x)
    outcomes.append(random.choice(['H','T']))
    if outcomes[-1] == 'H':
        h += 1
        relative_freq.append(h/trials[-1])
    else:
        t += 1
        relative_freq.append(t/trials[-1])

df = pd.DataFrame({'trial_No' : trials, 'outcomes' : outcomes, 'relative_freq' : relative_freq})

plt.scatter()
# Out:
#      trial_No outcomes  relative_freq
# 0           1        T       1.000000
# 1           2        H       0.500000
# 2           3        H       0.666667
# 3           4        T       0.500000
# 4           5        H       0.600000
# ..        ...      ...            ...
# 995       996        H       0.505020
# 996       997        T       0.495486
# 997       998        T       0.495992
# 998       999        H       0.504505
# 999      1000        H       0.505000
#
# [1000 rows x 3 columns]

# %% [markdown]
# # Mean

# %%
np.random.seed(1)

data = np.random.normal(10,10,1000)

plt.scatter(data, list(range(len(data))),alpha=0.5,cmap='inferno', c=data)
